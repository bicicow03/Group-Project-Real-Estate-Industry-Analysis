# %%
import numpy as np
import pandas as pd

# %%
import glob
import os
# csv_files = glob.glob(os.path.join("../data/raw/domain/suburbs", "*.csv"))
# joined_suburbs = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True).sort_values(by='listing_id').reset_index(drop=True)

# print(len(joined_suburbs))
# joined_suburbs.head()

# %% [markdown]
# ### Data reading

# %%
all_suburbs = pd.read_csv("../data/raw/domain/vic_rentals_all.csv").sort_values(by='listing_id').reset_index(drop=True)
print(len(all_suburbs))
all_suburbs.head()
# Out:
# 12717
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...  floorplans_count virtual_tour primary_type           secondary_type  \
# 0  ...               0.0        False        House                    House
# 1  ...               0.0        False    Apartment  Apartment / Unit / Flat
# 2  ...               0.0        False    Apartment                   Studio
# 3  ...               0.0        False    Apartment  Apartment / Unit / Flat
# 4  ...               0.0        False    Apartment  Apartment / Unit / Flat
#
#                               agency agency_id             agent_names  \
# 0       Keyhole Property Investments    8749.0      Rentals, Reception
# 1               Raine & Horne Melton   22328.0                     NaN
# 2               Match Property Group    8668.0  Lisbeth Rosborg-Winter
# 3                      Simone Bullen    7896.0            Ebonnie Reid
# 4  Prime Property Partners Australia    2231.0           Maia Weinberg
#
#                                  structured_features  \
# 0  Air conditioning, Bath, Built in wardrobes, Cl...
# 1                                                NaN
# 2  Built in wardrobes, Furnished, Broadband inter...
# 3                                       Ground floor
# 4                                                NaN
#
#                                                  url  land_area
# 0  https://www.domain.com.au/68-francis-street-as...        NaN
# 1  https://www.domain.com.au/10-glenville-drive-m...        NaN
# 2  https://www.domain.com.au/32-546-flinders-stre...        NaN
# 3  https://www.domain.com.au/7-64-holmes-road-moo...        NaN
# 4  https://www.domain.com.au/1-60-the-avenue-prah...        NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Initial feature selection

# %%
all_suburbs.columns
# Out:
# Index(['listing_id', 'suburb', 'postcode', 'weekly_rent', 'bond',
#        'available_date', 'date_listed', 'days_listed', 'bedrooms', 'bathrooms',
#        'carspaces', 'property_type', 'address', 'lat', 'lon', 'scraped_date',
#        'domain_page_id', 'property_id', 'photo_count', 'video_count',
#        'floorplans_count', 'virtual_tour', 'primary_type', 'secondary_type',
#        'agency', 'agency_id', 'agent_names', 'structured_features', 'url',
#        'land_area'],
#       dtype='object')

# %%
DROPPED_COLUMNS = [
    "scraped_date",
    "domain_page_id",
    "property_id",
    "agency_id",
    "structured_features",
    "url",
]

# %%
all_suburbs = all_suburbs.drop(columns=DROPPED_COLUMNS)
all_suburbs.head()
# Out:
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...        lon photo_count video_count  floorplans_count  virtual_tour  \
# 0  ...  144.91820        12.0         0.0               0.0         False
# 1  ...  144.59305         6.0         0.0               0.0         False
# 2  ...  144.95618         1.0         0.0               0.0         False
# 3  ...  144.91553         7.0         0.0               0.0         False
# 4  ...  144.99860        12.0         0.0               0.0         False
#
#    primary_type           secondary_type                             agency  \
# 0         House                    House       Keyhole Property Investments
# 1     Apartment  Apartment / Unit / Flat               Raine & Horne Melton
# 2     Apartment                   Studio               Match Property Group
# 3     Apartment  Apartment / Unit / Flat                      Simone Bullen
# 4     Apartment  Apartment / Unit / Flat  Prime Property Partners Australia
#
#               agent_names land_area
# 0      Rentals, Reception       NaN
# 1                     NaN       NaN
# 2  Lisbeth Rosborg-Winter       NaN
# 3            Ebonnie Reid       NaN
# 4           Maia Weinberg       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Feature Engineering

# %%
all_suburbs
# Out:
#        listing_id           suburb  postcode  weekly_rent    bond  \
# 0         5470976       ASCOT VALE      3032        660.0  2868.0
# 1         5604062           MELTON      3337          NaN   150.0
# 2         6168570        MELBOURNE      3000        310.0  1347.0
# 3         7117948     MOONEE PONDS      3039        500.0  2173.0
# 4         7455074          PRAHRAN      3181          NaN   340.0
# ...           ...              ...       ...          ...     ...
# 12712    17754387       CRANBOURNE      3977        460.0  1999.0
# 12713    17754389  NORTH MELBOURNE      3051        720.0  3128.0
# 12714    17754400       SPRINGVALE      3171        650.0  2824.0
# 12715    17754418  NORTH MELBOURNE      3051        640.0  2780.0
# 12716    17754427      WHITE HILLS      3550        540.0  2340.0
#
#                      available_date date_listed  days_listed  bedrooms  \
# 0      Wednesday, 10 September 2025  2025-07-21         50.0       2.0
# 1          Tuesday, 15 January 2008  2008-01-15       6446.0       NaN
# 2              Monday, 03 July 2023  2025-09-02          7.0       NaN
# 3         Friday, 19 September 2025  2025-09-06          3.0       2.0
# 4             Thursday, 22 May 2014  2012-03-02       4938.0       1.0
# ...                             ...         ...          ...       ...
# 12712     Monday, 29 September 2025  2025-09-09          0.0       2.0
# 12713    Tuesday, 09 September 2025  2025-09-09          0.0       2.0
# 12714       Friday, 10 October 2025  2025-09-09          0.0       3.0
# 12715    Tuesday, 09 September 2025  2025-09-09          0.0       2.0
# 12716       Friday, 03 October 2025  2025-09-09          0.0       4.0
#
#        bathrooms  ...        lon photo_count video_count  floorplans_count  \
# 0            1.0  ...  144.91820        12.0         0.0               0.0
# 1            NaN  ...  144.59305         6.0         0.0               0.0
# 2            1.0  ...  144.95618         1.0         0.0               0.0
# 3            1.0  ...  144.91553         7.0         0.0               0.0
# 4            1.0  ...  144.99860        12.0         0.0               0.0
# ...          ...  ...        ...         ...         ...               ...
# 12712        1.0  ...  145.28055        10.0         0.0               0.0
# 12713        2.0  ...  144.93962        11.0         0.0               1.0
# 12714        2.0  ...  145.16086         8.0         0.0               0.0
# 12715        2.0  ...  144.93962         6.0         0.0               1.0
# 12716        2.0  ...  144.31300        13.0         0.0               0.0
#
#        virtual_tour     primary_type           secondary_type  \
# 0             False            House                    House
# 1             False        Apartment  Apartment / Unit / Flat
# 2             False        Apartment                   Studio
# 3             False        Apartment  Apartment / Unit / Flat
# 4             False        Apartment  Apartment / Unit / Flat
# ...             ...              ...                      ...
# 12712         False        Apartment  Apartment / Unit / Flat
# 12713         False        Apartment  Apartment / Unit / Flat
# 12714         False  Townhouse/Villa                Townhouse
# 12715         False        Apartment  Apartment / Unit / Flat
# 12716         False            House                    House
#
#                                    agency                 agent_names  \
# 0            Keyhole Property Investments          Rentals, Reception
# 1                    Raine & Horne Melton                         NaN
# 2                    Match Property Group      Lisbeth Rosborg-Winter
# 3                           Simone Bullen                Ebonnie Reid
# 4       Prime Property Partners Australia               Maia Weinberg
# ...                                   ...                         ...
# 12712            Finning First National      Property Management Team
# 12713   COMPASS REAL ESTATE (VIC) PTY LTD               Sonita Dawood
# 12714  Buxton Real Estate Dingley Village      Nava Shams, Kelly Amor
# 12715   COMPASS REAL ESTATE (VIC) PTY LTD               Sonita Dawood
# 12716              PRD Nationwide Bendigo  Jessica Walsh, Lily Blabey
#
#       land_area
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 12712       NaN
# 12713       NaN
# 12714       NaN
# 12715       NaN
# 12716       NaN
#
# [12717 rows x 24 columns]

# %% [markdown]
# #### Merging with transport data

# %%
def find_num_stops_within_radius(property_lat, property_lon, stops_df, radius_km):
    """
    Calculate the number of transport stops within a given radius (in km) of a property.

    Parameters:
    property_lat (float): Latitude of the property
    property_lon (float): Longitude of the property
    stops_df (DataFrame): DataFrame containing transport stops with 'Latitude' and 'Longitude' columns
    radius_km (float): Radius in kilometers

    Returns:
    int: Number of stops within the specified radius
    """
    # Haversine formula
    lat_diff = np.radians(stops_df['Latitude'] - property_lat)
    lon_diff = np.radians(stops_df['Longitude'] - property_lon)

    a = np.sin(lat_diff / 2)**2 + np.cos(np.radians(property_lat)) * \
        np.cos(np.radians(stops_df['Latitude'])) * np.sin(lon_diff / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    distances_km = 6371 * c  # Earth radius in km

    # Mask for rows within radius
    mask = distances_km <= radius_km
    stops_within_radius = stops_df[mask]

    # Print matching rows
    # print(stops_within_radius)

    return np.sum(mask)

def return_stop_insights_per_type(property_lat, property_lon, stops_df, radius):
    output = dict()
    output["NumMetroBusStops"] = find_num_stops_within_radius(
        property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Bus"], radius)
    output["NumMetroTramStops"] = find_num_stops_within_radius(
        property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Tram"], radius)
    output["NumMetroTrainStops"] = find_num_stops_within_radius(
        property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Train"], radius)
    output["NumRegionalTrainStops"] = find_num_stops_within_radius(
        property_lat, property_lon, stops_df[stops_df["StopType"] == "Regional Train"], radius)
    output["NumRegionalBusStops"] = find_num_stops_within_radius(
        property_lat, property_lon, stops_df[stops_df["StopType"] == "Regional Bus"], radius)
    return output

def return_stop_insights_metro_bus(property_lat, property_lon, stops_df, radius):
    return find_num_stops_within_radius(property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Bus"], radius)

def return_stop_insights_metro_tram(property_lat, property_lon, stops_df, radius):
    return find_num_stops_within_radius(property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Tram"], radius)

def return_stop_insights_metro_train(property_lat, property_lon, stops_df, radius):
    return find_num_stops_within_radius(property_lat, property_lon, stops_df[stops_df["StopType"] == "Metro Train"], radius)

def return_stop_insights_regional_train(property_lat, property_lon, stops_df, radius):
    return find_num_stops_within_radius(property_lat, property_lon, stops_df[stops_df["StopType"] == "Regional Train"], radius)

def return_stop_insights_regional_bus(property_lat, property_lon, stops_df, radius):
    return find_num_stops_within_radius(property_lat, property_lon, stops_df[stops_df["StopType"] == "Regional Bus"], radius)

# %%
RADIUS = 2 # 2km
transport_data = pd.read_csv("../data/processed/transport/transport_stops.csv")
transport_data.head()
# Out:
#                                 StopName   StopType   Latitude   Longitude
# 0                           10 Jarrah Dr  Metro Bus -38.002837  145.110716
# 1                             10 Oban Rd  Metro Bus -37.796342  145.252047
# 2                          10 Queens Pde  Metro Bus -37.719582  144.971255
# 3                100 South Gippsland Hwy  Metro Bus -38.008999  145.229229
# 4  1000 Steps/Mount Dandenong Tourist Rd  Metro Bus -37.889758  145.318343

# %%
# 3 mins to run
all_suburbs["num_metro_bus_stops"] = all_suburbs.apply(lambda row: return_stop_insights_metro_bus(row["lat"], row["lon"], transport_data, RADIUS), axis=1)
all_suburbs["num_metro_tram_stops"] = all_suburbs.apply(lambda row: return_stop_insights_metro_tram(row["lat"], row["lon"], transport_data, RADIUS), axis=1)
all_suburbs["num_metro_train_stops"] = all_suburbs.apply(lambda row: return_stop_insights_metro_train(row["lat"], row["lon"], transport_data, RADIUS), axis=1)
all_suburbs["num_regional_bus_stops"] = all_suburbs.apply(lambda row: return_stop_insights_regional_bus(row["lat"], row["lon"], transport_data, RADIUS), axis=1)
all_suburbs["num_regional_train_stops"] = all_suburbs.apply(lambda row: return_stop_insights_regional_train(row["lat"], row["lon"], transport_data, RADIUS), axis=1)
all_suburbs.head()
# Out:
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...  primary_type           secondary_type  \
# 0  ...         House                    House
# 1  ...     Apartment  Apartment / Unit / Flat
# 2  ...     Apartment                   Studio
# 3  ...     Apartment  Apartment / Unit / Flat
# 4  ...     Apartment  Apartment / Unit / Flat
#
#                               agency             agent_names  land_area  \
# 0       Keyhole Property Investments      Rentals, Reception        NaN
# 1               Raine & Horne Melton                     NaN        NaN
# 2               Match Property Group  Lisbeth Rosborg-Winter        NaN
# 3                      Simone Bullen            Ebonnie Reid        NaN
# 4  Prime Property Partners Australia           Maia Weinberg        NaN
#
#    num_metro_bus_stops  num_metro_tram_stops  num_metro_train_stops  \
# 0                   83                    38                      4
# 1                   35                     0                      0
# 2                   85                   108                      6
# 3                  129                    40                      3
# 4                   85                   100                      7
#
#   num_regional_bus_stops num_regional_train_stops
# 0                      0                        0
# 1                      0                        0
# 2                      0                        3
# 3                      0                        1
# 4                      0                        0
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Merging with school location data

# %%
# Load processed school location data
school_data = pd.read_csv("../data/processed/schools/school_locations.csv")
school_data.head()

# Function to count schools within a radius of each property using haversine formula
from numpy import radians, cos, sin, sqrt, arctan2
def count_schools_within_radius(lat, lon, school_df, radius_km=2):
    R = 6371  # Earth radius in km
    lat1 = radians(lat)
    lon1 = radians(lon)
    lats2 = radians(school_df['Latitude'])
    lons2 = radians(school_df['Longitude'])
    dlat = lats2 - lat1
    dlon = lons2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lats2) * sin(dlon/2)**2
    c = 2 * arctan2(sqrt(a), sqrt(1-a))
    distances = R * c
    return (distances < radius_km).sum()

# Add feature: number of schools within 2km of each property
all_suburbs['num_schools_2km'] = all_suburbs.apply(lambda row: count_schools_within_radius(row['lat'], row['lon'], school_data, radius_km=2), axis=1)
all_suburbs.head()
# Out:
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...           secondary_type                             agency  \
# 0  ...                    House       Keyhole Property Investments
# 1  ...  Apartment / Unit / Flat               Raine & Horne Melton
# 2  ...                   Studio               Match Property Group
# 3  ...  Apartment / Unit / Flat                      Simone Bullen
# 4  ...  Apartment / Unit / Flat  Prime Property Partners Australia
#
#               agent_names  land_area  num_metro_bus_stops  \
# 0      Rentals, Reception        NaN                   83
# 1                     NaN        NaN                   35
# 2  Lisbeth Rosborg-Winter        NaN                   85
# 3            Ebonnie Reid        NaN                  129
# 4           Maia Weinberg        NaN                   85
#
#    num_metro_tram_stops  num_metro_train_stops  num_regional_bus_stops  \
# 0                    38                      4                       0
# 1                     0                      0                       0
# 2                   108                      6                       0
# 3                    40                      3                       0
# 4                   100                      7                       0
#
#   num_regional_train_stops num_schools_2km
# 0                        0              13
# 1                        0               6
# 2                        3              11
# 3                        1              13
# 4                        0              21
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Merging with census data

# %% [markdown]
# Merging all_subrubs with census data based on the shape file coordinates

# %%
import geopandas as gdp
from shapely.geometry import Point
import pandas as pd

census=gdp.read_file("../data/processed/demographics/sa2_census.geojson")

geometry = [Point(xy) for xy in zip(all_suburbs["lon"], all_suburbs["lat"])]
suburbs_gdf=gdp.GeoDataFrame(all_suburbs, geometry=geometry, crs="EPSG:7844")

# Reproject real estate to census CRS
suburbs_gdf=suburbs_gdf.to_crs(census.crs)

# Each point inherits the SA2 attributes from census polygons
merged=gdp.sjoin(suburbs_gdf, census, how="left", predicate="within")

dropped_columns=["SA2_CODE_2021", "SA2_NAME21", "SA3_CODE21", "SA3_NAME21", "geometry", "index_right"]

all_suburbs=merged.drop(columns=dropped_columns)

all_suburbs.head()
# Out:
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...  Mortgage (%) Total rented (%) Other tenure (%)  Unemployment  \
# 0  ...      0.327294         0.379467         0.009730      0.046495
# 1  ...      0.297929         0.346025         0.011022      0.095581
# 2  ...      0.123647         0.761911         0.018286      0.083853
# 3  ...      0.289420         0.385893         0.013116      0.038438
# 4  ...      0.237092         0.549360         0.014147      0.036782
#
#    post_gradutae (%)  Graduate_diploma_certificate(%)  Bachelor (%)  \
# 0           0.168135                         0.065559      0.382874
# 1           0.030909                         0.025455      0.129697
# 2           0.219751                         0.025098      0.416040
# 3           0.170695                         0.073617      0.393366
# 4           0.164398                         0.050746      0.458828
#
#    Advanced_&_Diploma (%) Certificate_level (%) Total_persons
# 0                0.119857              0.158769        8969.0
# 1                0.143939              0.413333        3300.0
# 2                0.123610              0.081344       12232.0
# 3                0.134493              0.153807        9889.0
# 4                0.118529              0.110812       13735.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Merging with population growth

# %%
population = pd.read_csv("../data/processed/population/population_final.csv")
all_suburbs = all_suburbs.merge(population, how="left", on="postcode")
all_suburbs = all_suburbs.drop(columns=["SA2 code"])

# %%
all_suburbs.head()
# Out:
#    listing_id        suburb  postcode  weekly_rent    bond  \
# 0     5470976    ASCOT VALE      3032        660.0  2868.0
# 1     5604062        MELTON      3337          NaN   150.0
# 2     6168570     MELBOURNE      3000        310.0  1347.0
# 3     7117948  MOONEE PONDS      3039        500.0  2173.0
# 4     7455074       PRAHRAN      3181          NaN   340.0
#
#                  available_date date_listed  days_listed  bedrooms  bathrooms  \
# 0  Wednesday, 10 September 2025  2025-07-21         50.0       2.0        1.0
# 1      Tuesday, 15 January 2008  2008-01-15       6446.0       NaN        NaN
# 2          Monday, 03 July 2023  2025-09-02          7.0       NaN        1.0
# 3     Friday, 19 September 2025  2025-09-06          3.0       2.0        1.0
# 4         Thursday, 22 May 2014  2012-03-02       4938.0       1.0        1.0
#
#    ...  Total rented (%) Other tenure (%) Unemployment  post_gradutae (%)  \
# 0  ...          0.379467         0.009730     0.046495           0.168135
# 1  ...          0.346025         0.011022     0.095581           0.030909
# 2  ...          0.761911         0.018286     0.083853           0.219751
# 3  ...          0.385893         0.013116     0.038438           0.170695
# 4  ...          0.549360         0.014147     0.036782           0.164398
#
#    Graduate_diploma_certificate(%)  Bachelor (%)  Advanced_&_Diploma (%)  \
# 0                         0.065559      0.382874                0.119857
# 1                         0.025455      0.129697                0.143939
# 2                         0.025098      0.416040                0.123610
# 3                         0.073617      0.393366                0.134493
# 4                         0.050746      0.458828                0.118529
#
#    Certificate_level (%) Total_persons Population-2023
# 0               0.158769        8969.0           13408
# 1               0.413333        3300.0            8011
# 2               0.081344       12232.0           18017
# 3               0.153807        9889.0           17203
# 4               0.110812       13735.0           20268
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Merging with crime

# %%
suburb_crime = pd.read_csv("../data/processed/crime/suburb_crime_final.csv")

# %% [markdown]
# #### Standardising suburb names for merge

# %%
# Manually remove these suburbs which do not appear in the real estate data
# Golden Point (Ballarat - Vic.) or Golden Point (Mount Alexander - Vic.), keep former (postcode 3350)
# Hillside (East Gippsland - Vic.) or Hillside (Melton - Vic.), keep latter (postcode 3037)
# Merrijig (East Gippsland - Vic.) or Merrijig (Mansfield - Vic.), keep latter (postcode 3723)

suburb_crime = suburb_crime[suburb_crime["SAL_NAME21"] != "Golden Point (Mount Alexander - Vic.)"]
suburb_crime = suburb_crime[suburb_crime["SAL_NAME21"] != "Hillside (East Gippsland - Vic.)"]
suburb_crime = suburb_crime[suburb_crime["SAL_NAME21"] != "Merrijig (East Gippsland - Vic.)"]

# Remove (), e.g. Lalor (VIC.) -> Lalor and Golden Point (Mount Alexander - Vic.) -> Golden point
suburb_crime["SAL_NAME21"] = suburb_crime["SAL_NAME21"].str.replace(r" \(.*\)", "", regex=True)

# Capitalise
suburb_crime["SAL_NAME21"] = suburb_crime["SAL_NAME21"].str.upper()
all_suburbs["suburb"] = all_suburbs["suburb"].str.upper()

# # Remove (.VIC) from crime suburbs
# suburb_crime["SAL_NAME21"] = suburb_crime["SAL_NAME21"].str.replace(r" \(VIC.\)", "", regex=True)


# There are multiple rows per crime suburb for different years, only interested in 2025
suburb_crime = suburb_crime[suburb_crime["year"] == 2025]

# Drop redundant columns
suburb_crime = suburb_crime.drop(columns=["year", "LOCI_URI21", "index_right", "STE_CODE21", "STE_NAME21", "AUS_CODE21", "AUS_NAME21"])

# Some suburbs belong to multiple lga, but we only want 1 row per suburb, hence group by suburb and take mean of columns: 
# [incidents_recorded, rate_per_100000_population, population_est, crime_per_person, crime_index, crime_rank]
suburb_crime = suburb_crime.groupby("SAL_NAME21").agg({
    "incidents_recorded": "mean",
    "rate_per_100000_population": "mean",
    "population_est": "mean",
    "crime_per_person": "mean",
    "crime_index": "mean",
    "crime_rank": "mean"
}).reset_index()

suburb_crime.reset_index(drop=True, inplace=True)
suburb_crime
# Out:
#       SAL_NAME21  incidents_recorded  rate_per_100000_population  \
# 0       ABBEYARD              1179.0                 4592.216153
# 1     ABBOTSFORD             10393.5                 8541.436737
# 2     ABERFELDIE              8933.0                 8218.304590
# 3      ABERFELDY              4001.0                 6339.853611
# 4        ACHERON               512.0                 3262.088399
# ...          ...                 ...                         ...
# 2842     YUNDOOL              1458.5                 6791.012931
# 2843      YUROKE             17321.0                 6180.821302
# 2844     YUULONG               655.0                 4149.701507
# 2845     ZEERUST              7102.0                10069.087487
# 2846   ZUMSTEINS              1231.0                 7536.224619
#
#       population_est  crime_per_person  crime_index  crime_rank
# 0       21780.969150          0.045922     0.814679  509.500000
# 1      140838.116500          0.085414     1.515288  291.500000
# 2      113231.151125          0.082183     1.457963  162.000000
# 3       63108.712680          0.063399     1.124717  267.000000
# 4       15695.466750          0.032621     0.578709  721.000000
# ...              ...               ...          ...         ...
# 2842    22846.702790          0.067910     1.204755  237.500000
# 2843   280237.838200          0.061808     1.096504  284.000000
# 2844    15784.267830          0.041497     0.736175  592.000000
# 2845    70532.707250          0.100691     1.786300   35.000000
# 2846    16242.926980          0.075362     1.336959  162.333333
#
# [2847 rows x 7 columns]

# %% [markdown]
# Find which suburb names in crime dataset are not in all suburbs dataset

# %%
crime_suburbs = suburb_crime["SAL_NAME21"].unique()
suburbs = all_suburbs["suburb"].unique()
print((len(crime_suburbs), len(suburbs)))

# Find which suburb names in crime dataset are not in all suburbs dataset, 
# these aren't an issue as they will just not get merged
crime_suburbs_not_in_all_suburbs = set(crime_suburbs).difference(set(suburbs))
print(len(crime_suburbs_not_in_all_suburbs))

# Find which suburb names in all suburbs dataset are not in crime dataset
# Should aim to minimise to 0
suburbs_not_in_crime = set(suburbs).difference(set(crime_suburbs))
print(len(suburbs_not_in_crime))

# After research, these suburbs do not have crime data, so nothing we can do except just remove when merging
print(suburbs_not_in_crime)
# Out:
# (2847, 654)
# 2216
# 23
# {'MORDIALLOC', 'BARONGAROOK', 'BLACK ROCK', 'HIGHETT', 'BONBEACH', 'HIDDEN VALLEY', 'FORREST', 'HEATHERTON', 'HAMPTON EAST', 'HAMPTON', 'TRARALGON', 'CHURCHILL', 'PARKDALE', 'ASPENDALE', 'CHELSEA', 'SANDRINGHAM', 'NEWBOROUGH', 'MORWELL', 'EDITHVALE', 'MENTONE', 'CHELTENHAM', 'BEAUMARIS', 'COLAC'}

# %%
all_suburbs = all_suburbs[~all_suburbs["suburb"].isin(suburbs_not_in_crime)]

# %%
all_suburbs = all_suburbs.merge(
    suburb_crime,
    how="left",
    left_on="suburb",     # from rental dataset
    right_on="SAL_NAME21"   # from crime dataset
)

# %%
all_suburbs
# Out:
#        listing_id           suburb  postcode  weekly_rent    bond  \
# 0         5470976       ASCOT VALE      3032        660.0  2868.0
# 1         5604062           MELTON      3337          NaN   150.0
# 2         6168570        MELBOURNE      3000        310.0  1347.0
# 3         7117948     MOONEE PONDS      3039        500.0  2173.0
# 4         7455074          PRAHRAN      3181          NaN   340.0
# ...           ...              ...       ...          ...     ...
# 12326    17754387       CRANBOURNE      3977        460.0  1999.0
# 12327    17754389  NORTH MELBOURNE      3051        720.0  3128.0
# 12328    17754400       SPRINGVALE      3171        650.0  2824.0
# 12329    17754418  NORTH MELBOURNE      3051        640.0  2780.0
# 12330    17754427      WHITE HILLS      3550        540.0  2340.0
#
#                      available_date date_listed  days_listed  bedrooms  \
# 0      Wednesday, 10 September 2025  2025-07-21         50.0       2.0
# 1          Tuesday, 15 January 2008  2008-01-15       6446.0       NaN
# 2              Monday, 03 July 2023  2025-09-02          7.0       NaN
# 3         Friday, 19 September 2025  2025-09-06          3.0       2.0
# 4             Thursday, 22 May 2014  2012-03-02       4938.0       1.0
# ...                             ...         ...          ...       ...
# 12326     Monday, 29 September 2025  2025-09-09          0.0       2.0
# 12327    Tuesday, 09 September 2025  2025-09-09          0.0       2.0
# 12328       Friday, 10 October 2025  2025-09-09          0.0       3.0
# 12329    Tuesday, 09 September 2025  2025-09-09          0.0       2.0
# 12330       Friday, 03 October 2025  2025-09-09          0.0       4.0
#
#        bathrooms  ...  Certificate_level (%) Total_persons Population-2023  \
# 0            1.0  ...               0.158769        8969.0           13408
# 1            NaN  ...               0.413333        3300.0            8011
# 2            1.0  ...               0.081344       12232.0           18017
# 3            1.0  ...               0.153807        9889.0           17203
# 4            1.0  ...               0.110812       13735.0           20268
# ...          ...  ...                    ...           ...             ...
# 12326        1.0  ...               0.396929        9314.0           13530
# 12327        2.0  ...               0.087128       10651.0           18017
# 12328        2.0  ...               0.199609        9198.0           23509
# 12329        2.0  ...               0.087128       10651.0           18017
# 12330        2.0  ...               0.434545        6577.0           15236
#
#             SAL_NAME21  incidents_recorded  rate_per_100000_population  \
# 0           ASCOT VALE        16262.250000                10220.714480
# 1               MELTON        11912.000000                 5103.404254
# 2            MELBOURNE        17715.250000                12685.718229
# 3         MOONEE PONDS        10143.000000                 7696.915003
# 4              PRAHRAN        19274.333333                12658.554200
# ...                ...                 ...                         ...
# 12326       CRANBOURNE        21416.000000                 5128.123281
# 12327  NORTH MELBOURNE        34620.000000                17792.112910
# 12328       SPRINGVALE        14568.500000                 7901.140204
# 12329  NORTH MELBOURNE        34620.000000                17792.112910
# 12330      WHITE HILLS         9525.000000                 7471.272827
#
#        population_est  crime_per_person crime_index  crime_rank
# 0       152460.693763          0.102207    1.813199  137.750000
# 1       233412.824200          0.051034    0.905366  447.000000
# 2       131663.822225          0.126857    2.250501   22.500000
# 3       138420.725117          0.076969    1.365466  183.000000
# 4       141511.437067          0.126586    2.245682   25.333333
# ...               ...               ...         ...         ...
# 12326   417618.665300          0.051281    0.909751  439.000000
# 12327   194580.599700          0.177921    3.156398    2.000000
# 12328   190296.130450          0.079011    1.401696  189.500000
# 12329   194580.599700          0.177921    3.156398    2.000000
# 12330   127488.317200          0.074713    1.325436  150.000000
#
# [12331 rows x 57 columns]

# %% [markdown]
# ### Exporting for preprocessing

# %%
all_suburbs.to_csv("../data/processed/real_estate/vic_rentals_all_enriched.csv", index=False)
